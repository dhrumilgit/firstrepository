# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\dhrumil\\Desktop\data.csv")

# %%
df
# Out:
#             PORTs            VESSELS NAME                         CARGO  \
# 0        KAKINADA            MV LADY AMNA                  BAGGED SUGAR
# 1          KANDLA             MV BARBOUNY                 SUGAR IN BAGS
# 2        KAKINADA     MV NAVIOUS LIBERTAS                     RAW SUGAR
# 3          KANDLA             MV ISLANDER                 SUGAR IN BAGS
# 4          KANDLA             MV CHARISMA  BRAZILIAN CANE VHP RAW SUGAR
# 5          KANDLA                MV HASAN           SUGAR / RICE IN BAG
# 6        KAKINADA      MV ANGLO BARINTHUS             RAW SUGAR IN BULK
# 7        KAKINADA         MV WARISA NAREE                          RICE
# 8        KAKINADA         MV THOESKEPASTI                  RICE IN BAGS
# 9        KAKINADA  MV TRUONG MINH FORTUNE                  RICE IN BAGS
# 10       KAKINADA        MV ASTRA PERSEUS                  RICE IN BAGS
# 11       KAKINADA               MV ALMASI                  RICE IN BAGS
# ...

# %%
df["QUANTITY"].max()
# Out:
# '76,675'

# %%
df.describe()
# Out:
#            PORTs VESSELS NAME         CARGO QUANTITY SHIPPER  \
# count         19           19            19       19      16
# unique         5           18            10       18      14
# top     KAKINADA  MV BARBOUNY  RICE IN BAGS   30,600   NALCO
# freq          10            2             5        2       2
#
#                       RECEIVER LOAD / DISCH PORT     COMMODITY  \
# count                       14                19            19
# unique                       9                13            10
# top     AFG GENERAL TRADING CO            BRAZIL  RICE IN BAGS
# freq                         3                 3             5
#
#        FINAL COMMODITY     M & NM
# count               19         19
# unique               2          2
# top               AGRI  NON-MAJOR
# freq                14         12
